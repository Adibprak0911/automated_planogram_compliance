# %% [markdown]
# importing libraries

# %%
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# detecting text

# %%
image = 'image_1.jpg'
reader = easyocr.Reader(['en'], gpu = False)
result = reader.readtext(image)
print(result)
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [([[169, 411], [605, 411], [605, 501], [169, 501]], 'TEMPORARILY', 0.9990462418300302), ([[161, 505], [617, 505], [617, 669], [161, 669]], 'OUT OF', 0.6485190088664852), ([[156, 659], [619, 659], [619, 816], [156, 816]], 'SERVICE', 0.9995325446850097), ([[185, 819], [589, 819], [589, 857], [185, 857]], 'sorry for the inconvenience', 0.9942733138845754)]

# %% [markdown]
# plotting

# %%
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]


img = cv2.imread(image)
img = cv2.rectangle(img,top_left, bottom_right, (255,0,0),5)
plt.imshow(img)
plt.show()
